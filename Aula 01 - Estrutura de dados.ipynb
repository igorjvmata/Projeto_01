# %%
#Divisão
10 // 3
# Out:
# 3

# %%
a = 4
b = 6
print(b)
# Out:
# 6

# %%
#Criando uma variável do tipo string
frase = "Python para análise de dados"

# %%
frase [0]
# Out:
# 'P'

# %%
frase [0:10]
# Out:
# 'Python par'

# %%
frase.count("do")
# Out:
# 1

# %%
frase.upper()
# Out:
# 'PYTHON PARA ANÁLISE DE DADOS'

# %%
frase.replace("Python","Frases")
# Out:
# 'Frases para análise de dados'

# %%
print(frase)
# Out:
# Python para análise de dados

# %%
animais = [1,2,3]
print(animais)
# Out:
# [1, 2, 3]

# %%
animais.remove(2)

# %%
print(animais)
# Out:
# [1, 3]

# %%
lista = [500,30,300,80,10]

# %%
max(lista)
# Out:
# 500

# %%
min(lista)
# Out:
# 10

# %%
animais.append("leao")

# %%
print(animais)
# Out:
# [1, 3, 'leao']

# %%
animais.extend(["cobra","gato"])

# %%
print(animais)
# Out:
# [1, 3, 'leao', 'cobra', 'gato']

# %%
animais.setdefault("Gata")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-fa2f4c1cca8a> in <module>
# ----> 1 animais.setdefault("Gata")
#
# AttributeError: 'list' object has no attribute 'setdefault'
